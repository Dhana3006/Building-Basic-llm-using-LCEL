# %%
# !pip install langchain
# !pip install langchain-chroma
# !pip install langchain_groq
# Out:
# Requirement already satisfied: langchain in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (1.2.10)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain) (1.2.17)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain) (1.0.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.14)
# Requirement already satisfied: packaging>=23.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (4.12.1)
# Requirement already satisfied: certifi in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Collecting langchain-chroma
#   Using cached langchain_chroma-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting chromadb<2.0.0,>=1.3.5 (from langchain-chroma)
#   Using cached chromadb-1.5.5-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.2 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-chroma) (1.2.17)
# Requirement already satisfied: numpy>=1.26.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-chroma) (2.4.2)
# Collecting build>=1.0.3 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached build-1.4.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pydantic>=2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.12.5)
# Requirement already satisfied: pydantic-settings>=2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.13.1)
# Collecting pybase64>=1.4.1 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached pybase64-1.4.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.41.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached onnxruntime-1.24.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (5.1 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached opentelemetry_api-1.40.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.40.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached opentelemetry_sdk-1.40.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.2)
# Collecting pypika>=0.48.9 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.7.0)
# Collecting importlib-resources (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached grpcio-1.78.0-cp311-cp311-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting bcrypt>=4.0.1 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.24.1)
# Collecting kubernetes>=28.1.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached kubernetes-35.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.0.3)
# Collecting mmh3>=4.0.1 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached mmh3-5.2.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.26.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.7.14)
# Requirement already satisfied: packaging>=23.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.25.0)
# Requirement already satisfied: anyio in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.12.1)
# Requirement already satisfied: certifi in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: attrs>=22.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.6.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading protobuf-7.34.0-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached googleapis_common_protos-1.73.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.40.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.40.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.40.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached opentelemetry_proto-1.40.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached protobuf-6.33.5-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting opentelemetry-semantic-conventions==0.61b0 (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic-settings>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.4.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.6.0)
# Requirement already satisfied: filelock>=3.10.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.1)
# Requirement already satisfied: click>=8.2.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.0.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached httptools-0.7.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached uvloop-0.22.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached watchfiles-1.1.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached websockets-16.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached langchain_chroma-1.1.0-py3-none-any.whl (12 kB)
# Using cached chromadb-1.5.5-cp39-abi3-macosx_11_0_arm64.whl (20.1 MB)
# Using cached bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl (495 kB)
# Using cached build-1.4.0-py3-none-any.whl (24 kB)
# Using cached grpcio-1.78.0-cp311-cp311-macosx_11_0_universal2.whl (11.8 MB)
# Using cached kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
# Using cached durationpy-0.10-py3-none-any.whl (3.9 kB)
# Using cached mmh3-5.2.1-cp311-cp311-macosx_11_0_arm64.whl (40 kB)
# Using cached onnxruntime-1.24.3-cp311-cp311-macosx_14_0_arm64.whl (17.3 MB)
# Using cached opentelemetry_api-1.40.0-py3-none-any.whl (68 kB)
# Using cached importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.40.0-py3-none-any.whl (20 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.40.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.40.0-py3-none-any.whl (72 kB)
# Using cached googleapis_common_protos-1.73.0-py3-none-any.whl (297 kB)
# Using cached opentelemetry_sdk-1.40.0-py3-none-any.whl (141 kB)
# Using cached opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl (231 kB)
# Using cached protobuf-6.33.5-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Using cached pybase64-1.4.3-cp311-cp311-macosx_11_0_arm64.whl (31 kB)
# Using cached pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Using cached httptools-0.7.1-cp311-cp311-macosx_11_0_arm64.whl (110 kB)
# Using cached uvloop-0.22.1-cp311-cp311-macosx_10_9_universal2.whl (1.4 MB)
# Using cached watchfiles-1.1.1-cp311-cp311-macosx_11_0_arm64.whl (394 kB)
# Using cached websockets-16.0-cp311-cp311-macosx_11_0_arm64.whl (175 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: pypika, mpmath, flatbuffers, durationpy, zipp, websockets, uvloop, sympy, pyproject_hooks, pybase64, protobuf, oauthlib, mmh3, importlib-resources, httptools, grpcio, bcrypt, watchfiles, requests-oauthlib, opentelemetry-proto, onnxruntime, importlib-metadata, googleapis-common-protos, build, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, kubernetes, opentelemetry-semantic-conventions, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb, langchain-chroma
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32/32 [langchain-chroma][chromadb]s]ry-api]
# Successfully installed bcrypt-5.0.0 build-1.4.0 chromadb-1.5.5 durationpy-0.10 flatbuffers-25.12.19 googleapis-common-protos-1.73.0 grpcio-1.78.0 httptools-0.7.1 importlib-metadata-8.7.1 importlib-resources-6.5.2 kubernetes-35.0.0 langchain-chroma-1.1.0 mmh3-5.2.1 mpmath-1.3.0 oauthlib-3.3.1 onnxruntime-1.24.3 opentelemetry-api-1.40.0 opentelemetry-exporter-otlp-proto-common-1.40.0 opentelemetry-exporter-otlp-proto-grpc-1.40.0 opentelemetry-proto-1.40.0 opentelemetry-sdk-1.40.0 opentelemetry-semantic-conventions-0.61b0 protobuf-6.33.5 pybase64-1.4.3 pypika-0.51.1 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 sympy-1.14.0 uvloop-0.22.1 watchfiles-1.1.1 websockets-16.0 zipp-3.23.0
# Requirement already satisfied: langchain_groq in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (1.1.2)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain_groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain_groq) (1.2.17)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.12.5)
# Requirement already satisfied: sniffio in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.11)
# Requirement already satisfied: certifi in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.7.14)
# Requirement already satisfied: packaging>=23.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.6.3)

# %%
from langchain_core.documents import Document

documents=[
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source": "mammal-pets-doc"},
    ),
Document(
    page_content="Cats are independent pets that often enjoy thier own space.",
    metadata={"source": "mammal-pets-doc"},
),
]

# %%
documents
# Out:
# [Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy thier own space.')]

# %%
import os
from dotenv import load_dotenv
load_dotenv()
from langchain_groq import ChatGroq
groq_api_key=os.getenv("GROQ_API_KEY")

os.environ["HF_TOKEN"]=os.getenv("HF_TOKEN")

llm=ChatGroq(groq_api_key=groq_api_key, model="llama-3.3-70b-versatile")
llm
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x13178dc90>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x132abcf50>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
# !pip install langchain_huggingface
# Out:
# Collecting langchain_huggingface
#   Using cached langchain_huggingface-1.2.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain_huggingface) (1.6.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.11 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain_huggingface) (1.2.17)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain_huggingface) (0.22.2)
# Requirement already satisfied: filelock>=3.10.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.4.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.67.3)
# Requirement already satisfied: typer in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.15.0)
# Requirement already satisfied: anyio in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.12.1)
# Requirement already satisfied: certifi in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.0.9)
# Requirement already satisfied: idna in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (0.7.14)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain_huggingface) (2.6.3)
# Requirement already satisfied: click>=8.2.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.1.2)
# Using cached langchain_huggingface-1.2.1-py3-none-any.whl (30 kB)
# Installing collected packages: langchain_huggingface
# Successfully installed langchain_huggingface-1.2.1

# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.3.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (5.3.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (1.6.0)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Using cached torch-2.10.0-2-cp311-none-macosx_11_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: numpy in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (2.4.2)
# Collecting scikit-learn (from sentence-transformers)
#   Using cached scikit_learn-1.8.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting scipy (from sentence-transformers)
#   Using cached scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.4.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.12.1)
# Requirement already satisfied: certifi in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Collecting networkx>=2.5.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Collecting joblib>=1.3.0 (from scikit-learn->sentence-transformers)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn->sentence-transformers)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click>=8.2.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Downloading sentence_transformers-5.3.0-py3-none-any.whl (512 kB)
# Using cached torch-2.10.0-2-cp311-none-macosx_11_0_arm64.whl (79.4 MB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached scikit_learn-1.8.0-cp311-cp311-macosx_12_0_arm64.whl (8.1 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl (20.3 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, networkx, joblib, torch, scikit-learn, sentence-transformers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [sentence-transformers]ence-transformers]
# Successfully installed joblib-1.5.3 networkx-3.6.1 scikit-learn-1.8.0 scipy-1.17.1 sentence-transformers-5.3.0 threadpoolctl-3.6.0 torch-2.10.0

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 from langchain_huggingface import HuggingFaceEmbeddings
# ----> 2 embeddings=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/langchain_huggingface/embeddings/huggingface.py:68, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      66 super().__init__(**kwargs)
#      67 try:
# ---> 68     import sentence_transformers  # type: ignore[import]
#      69 except ImportError as exc:
#      70     msg = (
#      71         "Could not import sentence_transformers python package. "
#      72         "Please install it with `pip install sentence-transformers`."
#      73     )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/cross_encoder/__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:35
#      33 from sentence_transformers import __version__
#      34 from sentence_transformers.backend import load_onnx_model, load_openvino_model
# ---> 35 from sentence_transformers.cross_encoder.fit_mixin import FitMixin
#      36 from sentence_transformers.cross_encoder.model_card import CrossEncoderModelCardData, generate_model_card
#      37 from sentence_transformers.cross_encoder.util import (
#      38     cross_encoder_init_args_decorator,
#      39     cross_encoder_predict_rank_args_decorator,
#      40 )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/cross_encoder/fit_mixin.py:20
#      17 from transformers.tokenization_utils_base import BatchEncoding
#      19 from sentence_transformers.cross_encoder.training_args import CrossEncoderTrainingArguments
# ---> 20 from sentence_transformers.datasets.NoDuplicatesDataLoader import NoDuplicatesDataLoader
#      21 from sentence_transformers.datasets.SentenceLabelDataset import SentenceLabelDataset
#      22 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/datasets/__init__.py:13
#      11 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#      12 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ---> 13 from .ParallelSentencesDataset import ParallelSentencesDataset
#      14 from .SentenceLabelDataset import SentenceLabelDataset
#      15 from .SentencesDataset import SentencesDataset
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/datasets/ParallelSentencesDataset.py:19
#      15 import random
#      17 from torch.utils.data import Dataset
# ---> 19 from sentence_transformers import SentenceTransformer
#      20 from sentence_transformers.readers import InputExample
#      22 logger = logging.getLogger(__name__)
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:45
#      43 from .fit_mixin import FitMixin
#      44 from .models import Pooling, Transformer
# ---> 45 from .peft_mixin import PeftAdapterMixin
#      46 from .quantization import quantize_embeddings
#      47 from .util import (
#      48     batch_to_device,
#      49     get_device_name,
#    (...)     55     truncate_embeddings,
#      56 )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/peft_mixin.py:5
#       1 from __future__ import annotations
#       3 from functools import wraps
# ----> 5 from transformers.integrations.peft import PeftAdapterMixin as PeftAdapterMixinTransformers
#       8 def peft_wrapper(func):
#       9     """Wrapper to call the method on the auto_model with a check for PEFT compatibility."""
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/integrations/peft.py:22
#      19 from dataclasses import replace
#      20 from typing import TYPE_CHECKING, Any, Literal, Optional
# ---> 22 from ..conversion_mapping import (
#      23     _MODEL_TO_CONVERSION_PATTERN,
#      24     get_checkpoint_conversion_mapping,
#      25     get_model_conversion_mapping,
#      26 )
#      27 from ..core_model_loading import (
#      28     Concatenate,
#      29     ConversionOps,
#    (...)     33     WeightRenaming,
#      34 )
#      35 from ..utils import (
#      36     CONFIG_NAME,
#      37     cached_file,
#    (...)     44     logging,
#      45 )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/conversion_mapping.py:20
#      17 from copy import deepcopy
#      18 from typing import TYPE_CHECKING
# ---> 20 from .core_model_loading import (
#      21     Chunk,
#      22     Concatenate,
#      23     ErnieFuseAndSplitTextVisionExperts,
#      24     Force16BytesAlignment,
#      25     MergeModulelist,
#      26     Transpose,
#      27     WeightConverter,
#      28     WeightRenaming,
#      29 )
#      32 if TYPE_CHECKING:
#      33     from .modeling_utils import PreTrainedModel
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/core_model_loading.py:34
#      30 from typing import TYPE_CHECKING, Any
#      32 import torch
# ---> 34 from .integrations.accelerate import get_device, offload_weight
#      35 from .integrations.tensor_parallel import ALL_PARALLEL_STYLES
#      36 from .utils import is_env_variable_true
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/integrations/accelerate.py:62
#      51     from ..quantizers import HfQuantizer
#      54 logger = logging.get_logger(__name__)
#      57 def get_module_size_with_ties(
#      58     tied_params,
#      59     module_size,
#      60     module_sizes,
#      61     modules_to_treat,
# ---> 62 ) -> tuple[int, list[str], list[nn.Module]]:
#      63     """
#      64     Calculate the total size of a module, including its tied parameters.
#      65
#    (...)     74         tied modules.
#      75     """
#      76     if len(tied_params) < 1:
#
# NameError: name 'nn' is not defined

# %%
## vectorstore db
from langchain_chroma import Chroma

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 from langchain_huggingface import HuggingFaceEmbeddings
# ----> 2 embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/langchain_huggingface/embeddings/huggingface.py:68, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      66 super().__init__(**kwargs)
#      67 try:
# ---> 68     import sentence_transformers  # type: ignore[import]
#      69 except ImportError as exc:
#      70     msg = (
#      71         "Could not import sentence_transformers python package. "
#      72         "Please install it with `pip install sentence-transformers`."
#      73     )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/cross_encoder/__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:35
#      33 from sentence_transformers import __version__
#      34 from sentence_transformers.backend import load_onnx_model, load_openvino_model
# ---> 35 from sentence_transformers.cross_encoder.fit_mixin import FitMixin
#      36 from sentence_transformers.cross_encoder.model_card import CrossEncoderModelCardData, generate_model_card
#      37 from sentence_transformers.cross_encoder.util import (
#      38     cross_encoder_init_args_decorator,
#      39     cross_encoder_predict_rank_args_decorator,
#      40 )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/cross_encoder/fit_mixin.py:24
#      22 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#      23 from sentence_transformers.readers import InputExample
# ---> 24 from sentence_transformers.SentenceTransformer import SentenceTransformer
#      25 from sentence_transformers.training_args import BatchSamplers
#      26 from sentence_transformers.util import is_datasets_available
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:45
#      43 from .fit_mixin import FitMixin
#      44 from .models import Pooling, Transformer
# ---> 45 from .peft_mixin import PeftAdapterMixin
#      46 from .quantization import quantize_embeddings
#      47 from .util import (
#      48     batch_to_device,
#      49     get_device_name,
#    (...)     55     truncate_embeddings,
#      56 )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/peft_mixin.py:5
#       1 from __future__ import annotations
#       3 from functools import wraps
# ----> 5 from transformers.integrations.peft import PeftAdapterMixin as PeftAdapterMixinTransformers
#       8 def peft_wrapper(func):
#       9     """Wrapper to call the method on the auto_model with a check for PEFT compatibility."""
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/integrations/peft.py:22
#      19 from dataclasses import replace
#      20 from typing import TYPE_CHECKING, Any, Literal, Optional
# ---> 22 from ..conversion_mapping import (
#      23     _MODEL_TO_CONVERSION_PATTERN,
#      24     get_checkpoint_conversion_mapping,
#      25     get_model_conversion_mapping,
#      26 )
#      27 from ..core_model_loading import (
#      28     Concatenate,
#      29     ConversionOps,
#    (...)     33     WeightRenaming,
#      34 )
#      35 from ..utils import (
#      36     CONFIG_NAME,
#      37     cached_file,
#    (...)     44     logging,
#      45 )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/conversion_mapping.py:20
#      17 from copy import deepcopy
#      18 from typing import TYPE_CHECKING
# ---> 20 from .core_model_loading import (
#      21     Chunk,
#      22     Concatenate,
#      23     ErnieFuseAndSplitTextVisionExperts,
#      24     Force16BytesAlignment,
#      25     MergeModulelist,
#      26     Transpose,
#      27     WeightConverter,
#      28     WeightRenaming,
#      29 )
#      32 if TYPE_CHECKING:
#      33     from .modeling_utils import PreTrainedModel
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/core_model_loading.py:34
#      30 from typing import TYPE_CHECKING, Any
#      32 import torch
# ---> 34 from .integrations.accelerate import get_device, offload_weight
#      35 from .integrations.tensor_parallel import ALL_PARALLEL_STYLES
#      36 from .utils import is_env_variable_true
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/integrations/accelerate.py:62
#      51     from ..quantizers import HfQuantizer
#      54 logger = logging.get_logger(__name__)
#      57 def get_module_size_with_ties(
#      58     tied_params,
#      59     module_size,
#      60     module_sizes,
#      61     modules_to_treat,
# ---> 62 ) -> tuple[int, list[str], list[nn.Module]]:
#      63     """
#      64     Calculate the total size of a module, including its tied parameters.
#      65
#    (...)     74         tied modules.
#      75     """
#      76     if len(tied_params) < 1:
#
# NameError: name 'nn' is not defined

# %%
# !pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (5.3.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (5.3.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: numpy in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (2.4.2)
# Requirement already satisfied: scikit-learn in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.4.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.12.1)
# Requirement already satisfied: certifi in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: click>=8.2.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 from langchain_huggingface import HuggingFaceEmbeddings
# ----> 2 embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/langchain_huggingface/embeddings/huggingface.py:68, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      66 super().__init__(**kwargs)
#      67 try:
# ---> 68     import sentence_transformers  # type: ignore[import]
#      69 except ImportError as exc:
#      70     msg = (
#      71         "Could not import sentence_transformers python package. "
#      72         "Please install it with `pip install sentence-transformers`."
#      73     )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/cross_encoder/__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:35
#      33 from sentence_transformers import __version__
#      34 from sentence_transformers.backend import load_onnx_model, load_openvino_model
# ---> 35 from sentence_transformers.cross_encoder.fit_mixin import FitMixin
#      36 from sentence_transformers.cross_encoder.model_card import CrossEncoderModelCardData, generate_model_card
#      37 from sentence_transformers.cross_encoder.util import (
#      38     cross_encoder_init_args_decorator,
#      39     cross_encoder_predict_rank_args_decorator,
#      40 )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/cross_encoder/fit_mixin.py:24
#      22 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#      23 from sentence_transformers.readers import InputExample
# ---> 24 from sentence_transformers.SentenceTransformer import SentenceTransformer
#      25 from sentence_transformers.training_args import BatchSamplers
#      26 from sentence_transformers.util import is_datasets_available
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:45
#      43 from .fit_mixin import FitMixin
#      44 from .models import Pooling, Transformer
# ---> 45 from .peft_mixin import PeftAdapterMixin
#      46 from .quantization import quantize_embeddings
#      47 from .util import (
#      48     batch_to_device,
#      49     get_device_name,
#    (...)     55     truncate_embeddings,
#      56 )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/peft_mixin.py:5
#       1 from __future__ import annotations
#       3 from functools import wraps
# ----> 5 from transformers.integrations.peft import PeftAdapterMixin as PeftAdapterMixinTransformers
#       8 def peft_wrapper(func):
#       9     """Wrapper to call the method on the auto_model with a check for PEFT compatibility."""
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/integrations/peft.py:22
#      19 from dataclasses import replace
#      20 from typing import TYPE_CHECKING, Any, Literal, Optional
# ---> 22 from ..conversion_mapping import (
#      23     _MODEL_TO_CONVERSION_PATTERN,
#      24     get_checkpoint_conversion_mapping,
#      25     get_model_conversion_mapping,
#      26 )
#      27 from ..core_model_loading import (
#      28     Concatenate,
#      29     ConversionOps,
#    (...)     33     WeightRenaming,
#      34 )
#      35 from ..utils import (
#      36     CONFIG_NAME,
#      37     cached_file,
#    (...)     44     logging,
#      45 )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/conversion_mapping.py:20
#      17 from copy import deepcopy
#      18 from typing import TYPE_CHECKING
# ---> 20 from .core_model_loading import (
#      21     Chunk,
#      22     Concatenate,
#      23     ErnieFuseAndSplitTextVisionExperts,
#      24     Force16BytesAlignment,
#      25     MergeModulelist,
#      26     Transpose,
#      27     WeightConverter,
#      28     WeightRenaming,
#      29 )
#      32 if TYPE_CHECKING:
#      33     from .modeling_utils import PreTrainedModel
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/core_model_loading.py:34
#      30 from typing import TYPE_CHECKING, Any
#      32 import torch
# ---> 34 from .integrations.accelerate import get_device, offload_weight
#      35 from .integrations.tensor_parallel import ALL_PARALLEL_STYLES
#      36 from .utils import is_env_variable_true
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/integrations/accelerate.py:62
#      51     from ..quantizers import HfQuantizer
#      54 logger = logging.get_logger(__name__)
#      57 def get_module_size_with_ties(
#      58     tied_params,
#      59     module_size,
#      60     module_sizes,
#      61     modules_to_treat,
# ---> 62 ) -> tuple[int, list[str], list[nn.Module]]:
#      63     """
#      64     Calculate the total size of a module, including its tied parameters.
#      65
#    (...)     74         tied modules.
#      75     """
#      76     if len(tied_params) < 1:
#
# NameError: name 'nn' is not defined

# %%
# !pip install sentence-transformers==2.7.0
# Out:
# Collecting sentence-transformers==2.7.0
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl.metadata (11 kB)
# Collecting transformers<5.0.0,>=4.34.0 (from sentence-transformers==2.7.0)
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: tqdm in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers==2.7.0) (4.67.3)
# Requirement already satisfied: torch>=1.11.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers==2.7.0) (2.10.0)
# Requirement already satisfied: numpy in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers==2.7.0) (2.4.2)
# Requirement already satisfied: scikit-learn in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers==2.7.0) (1.8.0)
# Requirement already satisfied: scipy in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers==2.7.0) (1.17.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers==2.7.0) (1.6.0)
# Collecting Pillow (from sentence-transformers==2.7.0)
#   Using cached pillow-12.1.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Requirement already satisfied: filelock in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==2.7.0) (3.25.2)
# Collecting huggingface-hub>=0.15.1 (from sentence-transformers==2.7.0)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==2.7.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==2.7.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==2.7.0) (2026.2.28)
# Requirement already satisfied: requests in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==2.7.0) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==2.7.0) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==2.7.0) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==2.7.0) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==2.7.0) (1.4.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==2.7.0) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==2.7.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==2.7.0) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==2.7.0) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers==2.7.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers==2.7.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests->transformers<5.0.0,>=4.34.0->sentence-transformers==2.7.0) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests->transformers<5.0.0,>=4.34.0->sentence-transformers==2.7.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests->transformers<5.0.0,>=4.34.0->sentence-transformers==2.7.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests->transformers<5.0.0,>=4.34.0->sentence-transformers==2.7.0) (2026.2.25)
# Requirement already satisfied: joblib>=1.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from scikit-learn->sentence-transformers==2.7.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from scikit-learn->sentence-transformers==2.7.0) (3.6.0)
# Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 25.3 MB/s  0:00:00eta 0:00:01
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 18.6 MB/s  0:00:00
# Using cached pillow-12.1.1-cp311-cp311-macosx_11_0_arm64.whl (4.7 MB)
# Installing collected packages: Pillow, huggingface-hub, transformers, sentence-transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.6.0
#     Uninstalling huggingface_hub-1.6.0:
#       Successfully uninstalled huggingface_hub-1.6.0
#   Attempting uninstall: transformersm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [huggingface-hub]
#     Found existing installation: transformers 5.3.0━━━━━━━━━━━ 1/4 [huggingface-hub]
#     Uninstalling transformers-5.3.0:━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [huggingface-hub]
#       Successfully uninstalled transformers-5.3.0━━━━━━━━━━━━━━━━━ 2/4 [transformers]
#   Attempting uninstall: sentence-transformers0m━━━━━━━━━━━━━━━━━━━ 2/4 [transformers]
#     Found existing installation: sentence-transformers 5.3.0━━ 2/4 [transformers]
#     Uninstalling sentence-transformers-5.3.0:━━━━━━━━━━━━━━━━━ 2/4 [transformers]
#       Successfully uninstalled sentence-transformers-5.3.0━━━━━━━━ 3/4 [sentence-transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [sentence-transformers]-transformers]
# Successfully installed Pillow-12.1.1 huggingface-hub-0.36.2 sentence-transformers-2.7.0 transformers-4.57.6

# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.1.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting numba>=0.51.0 (from librosa)
#   Downloading numba-0.64.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.22.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from librosa) (2.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from librosa) (1.17.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from librosa) (1.8.0)
# Requirement already satisfied: joblib>=1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from librosa) (5.2.1)
# Collecting soundfile>=0.12.1 (from librosa)
#   Downloading soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa)
#   Downloading pooch-1.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-1.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from librosa) (4.15.0)
# Collecting lazy_loader>=0.1 (from librosa)
#   Downloading lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Downloading msgpack-1.1.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: packaging in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from lazy_loader>=0.1->librosa) (25.0)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba>=0.51.0->librosa)
#   Downloading llvmlite-0.46.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pooch>=1.1->librosa) (4.9.4)
# Requirement already satisfied: requests>=2.19.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.2.25)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (3.0)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading audioread-3.1.0-py3-none-any.whl (23 kB)
# Downloading lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Downloading msgpack-1.1.2-cp311-cp311-macosx_11_0_arm64.whl (84 kB)
# Downloading numba-0.64.0-cp311-cp311-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 11.8 MB/s  0:00:00 eta 0:00:01
# Downloading llvmlite-0.46.0-cp311-cp311-macosx_11_0_arm64.whl (37.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 37.7 MB/s  0:00:00 eta 0:00:01
# Downloading pooch-1.9.0-py3-none-any.whl (67 kB)
# Downloading soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.4 MB/s  0:00:00
# Downloading soxr-1.0.0-cp311-cp311-macosx_11_0_arm64.whl (165 kB)
# Installing collected packages: soxr, msgpack, llvmlite, lazy_loader, audioread, soundfile, pooch, numba, librosa
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [librosa]m7/9 [numba]te]
# Successfully installed audioread-3.1.0 lazy_loader-0.5 librosa-0.11.0 llvmlite-0.46.0 msgpack-1.1.2 numba-0.64.0 pooch-1.9.0 soundfile-0.13.1 soxr-1.0.0

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 from langchain_huggingface import HuggingFaceEmbeddings
# ----> 2 embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/langchain_huggingface/embeddings/huggingface.py:97, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      94 else:
#      95     model_cls = sentence_transformers.SentenceTransformer
# ---> 97 self._client = model_cls(
#      98     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#      99 )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:197, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, token, use_auth_token, truncate_dim)
#     194         model_name_or_path = __MODEL_HUB_ORGANIZATION__ + "/" + model_name_or_path
#     196 if is_sentence_transformer_model(model_name_or_path, token, cache_folder=cache_folder, revision=revision):
# --> 197     modules = self._load_sbert_model(
#     198         model_name_or_path,
#     199         token=token,
#     200         cache_folder=cache_folder,
#     201         revision=revision,
#     202         trust_remote_code=trust_remote_code,
#     203     )
#     204 else:
#     205     modules = self._load_auto_model(
#     206         model_name_or_path,
#     207         token=token,
#    (...)    210         trust_remote_code=trust_remote_code,
#     211     )
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:1296, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code)
#    1294     else:
#    1295         kwargs["tokenizer_args"] = hub_kwargs
# -> 1296     module = Transformer(model_name_or_path, cache_dir=cache_folder, **kwargs)
#    1297 else:
#    1298     # Normalize does not require any files to be loaded
#    1299     if module_class == Normalize:
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:120, in __init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path, backend)
#     116 def tokenize(self, texts: Union[List[str], List[Dict], List[Tuple[str, str]]], padding: Union[str, bool] = True):
#     117     """
#     118     Tokenizes a text and maps tokens to token-ids
#     119     """
# --> 120     output = {}
#     121     if isinstance(texts[0], str):
#     122         to_tokenize = [texts]
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:195, in _load_config(self, model_name_or_path, cache_dir, backend, config_args)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/models/auto/configuration_auto.py:1457, in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/models/auto/configuration_auto.py:1164, in __getitem__(self, key)
#    1157     lines = [
#    1158         f"{indent}- **{model_type}** -- {model_type_to_name[model_type]} ({MODEL_NAMES_MAPPING[model_type]} model)"
#    1159         for model_type in sorted(model_type_to_name.keys())
#    1160     ]
#    1161 else:
#    1162     config_to_name = {
#    1163         CONFIG_MAPPING_NAMES[config]: _get_class_name(clas)
# -> 1164         for config, clas in config_to_class.items()
#    1165         if config in CONFIG_MAPPING_NAMES
#    1166     }
#    1167     config_to_model_name = {
#    1168         config: MODEL_NAMES_MAPPING[model_type] for model_type, config in CONFIG_MAPPING_NAMES.items()
#    1169     }
#    1170     lines = [
#    1171         f"{indent}- [`{config_name}`] configuration class:"
#    1172         f" {config_to_name[config_name]} ({config_to_model_name[config_name]} model)"
#    1173         for config_name in sorted(config_to_name.keys())
#    1174     ]
#
# File ~/.conda/envs/langchain-env/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/models/bert/__init__.py:32
#      29 import sys
#      31 _file = globals()["__file__"]
# ---> 32 sys.modules[__name__] = _LazyModule(__name__, _file, define_import_structure(_file), module_spec=__spec__)
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/transformers/utils/import_utils.py:2009, in __init__(self, name, module_file, import_structure, module_spec, extra_objects, explicit_import_shortcut)
#    2002 CCL_IMPORT_ERROR = """
#    2003 {0} requires the torch ccl library but it was not found in your environment. You can install it with pip:
#    2004 `pip install oneccl_bind_pt -f https://developer.intel.com/ipex-whl-stable`
#    2005 Please note that you may need to restart your runtime after installation.
#    2006 """
#    2008 # docstyle-ignore
# -> 2009 ESSENTIA_IMPORT_ERROR = """
#    2010 {0} requires essentia library. But that was not found in your environment. You can install them with pip:
#    2011 `pip install essentia==2.1b6.dev1034`
#    2012 Please note that you may need to restart your runtime after installation.
#    2013 """
#    2015 # docstyle-ignore
#    2016 LIBROSA_IMPORT_ERROR = """
#    2017 {0} requires the librosa library. But that was not found in your environment. You can install them with pip:
#    2018 `pip install librosa`
#    2019 Please note that you may need to restart your runtime after installation.
#    2020 """
#
# ValueError: Backend should be defined in the BACKENDS_MAPPING. Offending backend: tensorflow_text

# %%
# !pip install -U langchain-huggingface sentence-transformers huggingface-hub
# Out:
# 1741.41s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: langchain-huggingface in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (1.2.1)
# Requirement already satisfied: sentence-transformers in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (2.7.0)
# Collecting sentence-transformers
#   Using cached sentence_transformers-5.3.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: huggingface-hub in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (0.36.2)
# Collecting huggingface-hub
#   Downloading huggingface_hub-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.11 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-huggingface) (1.2.17)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: filelock>=3.10.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub) (2026.2.0)
# Collecting hf-xet<2.0.0,>=1.4.2 (from huggingface-hub)
#   Downloading hf_xet-1.4.2-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub) (4.67.3)
# Requirement already satisfied: typer in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub) (4.15.0)
# Requirement already satisfied: anyio in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub) (4.12.1)
# Requirement already satisfied: certifi in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub) (1.0.9)
# Requirement already satisfied: idna in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.7.14)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.4.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (4.57.6)
# Requirement already satisfied: torch>=1.11.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: numpy in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (2.4.2)
# Requirement already satisfied: scikit-learn in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.28)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from huggingface-hub) (1.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (2.6.3)
# Requirement already satisfied: sympy>=1.13.3 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: click>=8.2.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->huggingface-hub) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->huggingface-hub) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->huggingface-hub) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from typer->huggingface-hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from rich>=12.3.0->typer->huggingface-hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from rich>=12.3.0->typer->huggingface-hub) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub) (0.1.2)
# Downloading hf_xet-1.4.2-cp37-abi3-macosx_11_0_arm64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 17.9 MB/s  0:00:00 eta 0:00:01
# Using cached sentence_transformers-5.3.0-py3-none-any.whl (512 kB)
# Installing collected packages: hf-xet, sentence-transformers
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.4.1
#     Uninstalling hf-xet-1.4.1:
#       Successfully uninstalled hf-xet-1.4.1
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 2.7.0
#     Uninstalling sentence-transformers-2.7.0:
#       Successfully uninstalled sentence-transformers-2.7.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [sentence-transformers]ence-transformers]
# Successfully installed hf-xet-1.4.2 sentence-transformers-5.3.0

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
import os
from dotenv import load_dotenv
load_dotenv()
from langchain_groq import ChatGroq
groq_api_key=os.getenv("GROQ_API_KEY")

os.environ["HF_TOKEN"]=os.getenv("HF_TOKEN")

llm=ChatGroq(groq_api_key=groq_api_key, model="llama-3.3-70b-versatile")
llm
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x1752d3450>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x175422750>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.documents import Document

documents=[
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source": "mammal-pets-doc"},
    ),
Document(
    page_content="Cats are independent pets that often enjoy thier own space.",
    metadata={"source": "mammal-pets-doc"},
),
]

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
## vectorstores
from langchain_chroma import Chroma

vectorstore=Chroma.from_documents(documents,embedding=embeddings)
vectorstore

# %%
vectorstore.similarity_search("dog")
# Out:
# [Document(id='484c1e58-5c46-4c51-90bc-06aca59ab3a9', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(id='731f8886-d927-4517-8649-19562f062478', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy thier own space.')]

# %%
## Async query
await vectorstore.asimilarity_search("dog")
# Out:
# [Document(id='484c1e58-5c46-4c51-90bc-06aca59ab3a9', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(id='731f8886-d927-4517-8649-19562f062478', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy thier own space.')]

# %%
vectorstore.similarity_search_with_score("dog")
# Out:
# [(Document(id='484c1e58-5c46-4c51-90bc-06aca59ab3a9', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#   1.131113052368164),
#  (Document(id='731f8886-d927-4517-8649-19562f062478', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy thier own space.'),
#   1.5126497745513916)]

# %%
### retrievers
from typing import List
from langchain_core.documents import Document
from langchain_core.runnables import RunnableLambda

retriever=RunnableLambda(vectorstore.similarity_search).bind(k=1)
retriever.batch(["cat", "dog"])
# Out:
# [[Document(id='731f8886-d927-4517-8649-19562f062478', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy thier own space.')],
#  [Document(id='484c1e58-5c46-4c51-90bc-06aca59ab3a9', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.')]]

# %%
vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k":1}
)
retriever.batch(["cat", "dog"])
# Out:
# [[Document(id='731f8886-d927-4517-8649-19562f062478', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy thier own space.')],
#  [Document(id='484c1e58-5c46-4c51-90bc-06aca59ab3a9', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.')]]

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

message= """

Answer this question using the provided content only.

{question}

context:
{context}
"""
prompt= ChatPromptTemplate.from_messages([("human", message)])

rag_chain={"context":retriever, "question":RunnablePassthrough()}|prompt|llm
response= rag_chain.invoke("tell me about dogs")
print(response.content)
# Out:
# Dogs are great companions, known for their loyalty and friendliness.
