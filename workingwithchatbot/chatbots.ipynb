# %%
import os
from dotenv import load_dotenv
load_dotenv()  ## loading all the environment variables from .env file

groq_api_key=os.getenv("my_API_KEY")
groq_api_key

# %%
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
model=ChatGroq(model="llama-3.3-70b-versatile", groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x1125a6150>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x1128d0f50>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content="Hi, My name Dhana and I am learning Gen AI Course")])
# Out:
# AIMessage(content="Hello Dhana, nice to meet you. That's great to hear that you're learning about Gen AI (General Artificial Intelligence) course. Gen AI is a fascinating field that's rapidly evolving and has many exciting applications.\n\nWhat specific topics are you covering in your course, and what are your goals or interests in learning about Gen AI? I'm here to help and support you in your learning journey.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 48, 'total_tokens': 129, 'completion_time': 0.303236489, 'completion_tokens_details': None, 'prompt_time': 0.006390757, 'prompt_tokens_details': None, 'queue_time': 0.140881406, 'total_time': 0.309627246}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cdfd8-1822-79e3-a36e-8921aa879666-0', tool_calls=[], invalid_tool_calls=[], usage
# ...

# %%
from langchain_core.messages import AIMessage
model.invoke(
    [
        HumanMessage(content="Hi, My name Dhana and I am learning Gen AI Course"),
        AIMessage(content="Hello Dhana, nice to meet you. That's great to hear that you're learning about Gen AI (General Artificial Intelligence) course. Gen AI is a fascinating field that's rapidly evolving and has many exciting applications.\n\nWhat specific topics are you covering in your course, and what are your goals or interests in learning about Gen AI? I'm here to help and support you in your learning journey."),
        HumanMessage(content="Hey, what's my name and what I am learing?")
    ]
)
# Out:
# AIMessage(content='Your name is Dhana, and you are learning a Gen AI (General Artificial Intelligence) course.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 151, 'total_tokens': 172, 'completion_time': 0.029819409, 'completion_tokens_details': None, 'prompt_time': 0.015285455, 'prompt_tokens_details': None, 'queue_time': 0.139381686, 'total_time': 0.045104864}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cdfe3-28d9-7d91-9819-083afba353a7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 151, 'output_tokens': 21, 'total_tokens': 172})

# %%
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

store={}

def get_session_history(session_id:str)-> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id]=ChatMessageHistory()
    return store[session_id]

with_message_history=RunnableWithMessageHistory(model, get_session_history)

# %%
config={"configurable":{"session_id":"chat1"}}

# %%
response= with_message_history.invoke(
    [HumanMessage(content="Hi, My name Dhana and I am learning Gen AI Course")],
    config=config
)

# %%
response.content
# Out:
# "Hello again Dhana, welcome back. I see you're learning about General Artificial Intelligence (Gen AI). That's a great course to be taking. Gen AI has the potential to revolutionize many industries and aspects of our lives.\n\nWhat are your thoughts on the course so far? Are there any specific topics or concepts that you're finding particularly interesting or challenging? I'm here to help and provide any clarification or support you might need."

# %%
with_message_history.invoke(
    [HumanMessage(content="What is my name")],
    config=config,
)
# Out:
# AIMessage(content="Your name is Dhana. You've mentioned it a few times already.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 365, 'total_tokens': 381, 'completion_time': 0.038361044, 'completion_tokens_details': None, 'prompt_time': 0.018004453, 'prompt_tokens_details': None, 'queue_time': 0.008903173, 'total_time': 0.056365497}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_43d97c5965', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ce012-4e21-7bc3-9191-f5c1e4abe339-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 365, 'output_tokens': 16, 'total_tokens': 381})

# %%
## change the config--> session id
config1={"configurable":{"session_id": "chat2"}}
response=with_message_history.invoke(
    [HumanMessage(content="What is my name")],
    config=config1
)
response.content
# Out:
# "I don't know your name. I'm a large language model, I don't have the ability to know your personal information or recall previous conversations. Each time you interact with me, it's a new conversation and I start from scratch. If you'd like to share your name with me, I'd be happy to chat with you and use it in our conversation!"

# %%
response=with_message_history.invoke(
    [HumanMessage(content="my name is john")],
    config=config1
)
response.content
# Out:
# "Nice to meet you, John! It's great to have a name to associate with our conversation. I'll do my best to make our chat informative, helpful, and enjoyable. What's on your mind, John? Is there something specific you'd like to talk about or ask me?"

# %%
response=with_message_history.invoke(
    [HumanMessage(content="What is my name")],
    config=config1
)
response.content
# Out:
# 'I remember! Your name is John. We just established that a moment ago. Is everything okay, John? Did you just want to confirm that I remembered your name?'

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
prompt=ChatPromptTemplate.from_messages(
    [
        ("system", "you are a helpful assistant.Answer all the questions to the best of your ability"),
    MessagesPlaceholder(variable_name="messages")
    ]
)

chain=prompt|model

# %%
chain.invoke({"messages":[HumanMessage(content="Hi my name is Dhana")]})
# Out:
# AIMessage(content="Hello Dhana, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 57, 'total_tokens': 84, 'completion_time': 0.046037632, 'completion_tokens_details': None, 'prompt_time': 0.002195377, 'prompt_tokens_details': None, 'queue_time': 0.039412783, 'total_time': 0.048233009}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_bebe2dd4fb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ce054-bb6e-75d3-96f8-28ae90359548-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 57, 'output_tokens': 27, 'total_tokens': 84})

# %%
with_message_history=RunnableWithMessageHistory(chain,get_session_history)

# %%
config={"configurable": {"session_id": "chat3"}}
response=with_message_history.invoke(
    [HumanMessage(content="Hi my name is Dhana")],
    config=config
)
response
# Out:
# AIMessage(content="Hello Dhana, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 57, 'total_tokens': 84, 'completion_time': 0.04755208, 'completion_tokens_details': None, 'prompt_time': 0.002915795, 'prompt_tokens_details': None, 'queue_time': 0.139378699, 'total_time': 0.050467875}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ba38bbab80', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ce059-d1e7-7223-b33d-7f8d093aa3e5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 57, 'output_tokens': 27, 'total_tokens': 84})

# %%
## Add more complexity

prompt=ChatPromptTemplate.from_messages(
    [
        ("system", "you are a helpful assistant.Answer all the questions to the best of your ability in {language}"
        ),
    MessagesPlaceholder(variable_name="messages")
    ]
)

chain=prompt|model

# %%
response=chain.invoke({"messages":[HumanMessage(content="Hi my name is Dhana")], "language": "Hindi"})
response.content
# Out:
# 'नमस्ते धना, आपका स्वागत है! मैं आपकी कैसे मदद कर सकता हूँ?'

# %%
with_message_history=RunnableWithMessageHistory(
    chain,
    get_session_history,
    input_messages_key="messages"
)

# %%
config={"configurable": {"session_id": "chat4"}}
response=with_message_history.invoke(
    {'messages': [HumanMessage(content= "Hi, I am Dhana")], "language":"Hindi"},
    config=config
)
response.content
# Out:
# 'नमस्ते धना, मैं आपकी मदद के लिए यहाँ हूँ। मैं आपके प्रश्नों का उत्तर देने की पूरी कोशिश करूँगा। क्या आप कुछ पूछना चाहते हैं या किसी विशेष विषय पर चर्चा करना चाहते हैं?'

# %%
### manage the conversation history
import os
from dotenv import load_dotenv
load_dotenv()  ## loading all the environment variables from .env file

groq_api_key=os.getenv("my_API_KEY")
groq_api_key

# %%
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
model=ChatGroq(model="llama-3.3-70b-versatile", groq_api_key=groq_api_key)
model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from langchain_openai import ChatOpenAI
#       2 from langchain_groq import ChatGroq
#       3 model=ChatGroq(model="llama-3.3-70b-versatile", groq_api_key=groq_api_key)
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/langchain_openai/__init__.py:3
#       1 """Module for OpenAI integrations."""
# ----> 3 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       4 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#       5 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File ~/.conda/envs/langchain-env/lib/python3.11/site-packages/langchain_openai/chat_models/__init__.py:3
#       1 """Module for OpenAI chat models."""
# ----> 3 from langchain_openai.chat_models.azure import AzureChatOpenAI
# ...

# %%
# !pip install transformers

# %%
import sys
print(sys.executable)
# Out:
# /Users/narenderreddy/.conda/envs/langchain-env/bin/python

# %%
import sys
# !{sys.executable} -m pip install transformers

# %%
import IPython
IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    groq_api_key=os.getenv("GROQ_API_KEY")
)
# Out:
# PyTorch was not found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage, trim_messages

trimmer = trim_messages(
    max_tokens=45,
    strategy="last",
    token_counter=model,
    include_system=True,
    allow_partial=False,
    start_on="human"
)

messages = [
    SystemMessage(content="you are a good assistant"),
    HumanMessage(content="hi! I'm bob"),
    AIMessage(content="hi!"),
    HumanMessage(content="I like vanilla ice cream"),
    AIMessage(content="nice"),
    HumanMessage(content="whats 2+2"),
    AIMessage(content="4"),
    HumanMessage(content="thanks"),
    AIMessage(content="no problem"),
    HumanMessage(content="having fun?"),
    AIMessage(content="yes!"),
]

trimmer.invoke(messages)
# Out:
# [SystemMessage(content='you are a good assistant', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='I like vanilla ice cream', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='nice', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='whats 2+2', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='4', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='thanks', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='no problem', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='having fun?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='yes!', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
prompt=ChatPromptTemplate.from_messages(
    [
        ("system", "you are a helpful assistant.Answer all the questions to the best of your ability"),
    MessagesPlaceholder(variable_name="messages")
    ]
)

# %%
from operator import itemgetter

from langchain_core.runnables import RunnablePassthrough

chain=(
    RunnablePassthrough.assign(messages=itemgetter("messages")|trimmer)
    | prompt
    | model
)

response=chain.invoke(
    {"messages": messages + [HumanMessage(content="what ice cream do i ilke")],
    "language": "English"
    }
)
response.content
# Out:
# "I don't have that information. I'm a new conversation and don't have any prior knowledge about your preferences, including your favorite ice cream flavor. Would you like to share it with me?"

# %%
response= chain.invoke(
    {
        "messages": messages+[HumanMessage(content="what math problem did i ask")],
        "language": "English"
    }
)
response.content
# Out:
# 'You asked what 2 + 2 was. The answer is 4.'
