# %%
### Open AI API Key and open Source models-- llama3, Gemma2, mistral--groq

import os
from dotenv import load_dotenv
import openai
load_dotenv()

import os
openai.api_key = os.getenv("my_api_key")

groq_api_key = os.getenv("my_api_key")
groq_api_key

# %%
# !pip install langchain_groq
# Out:
# Collecting langchain_groq
#   Downloading langchain_groq-1.1.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain_groq)
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain_groq) (1.2.17)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.12.5)
# Requirement already satisfied: sniffio in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.11)
# Requirement already satisfied: certifi in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.7.14)
# Requirement already satisfied: packaging>=23.2.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/narenderreddy/.conda/envs/langchain-env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.6.3)
# Downloading langchain_groq-1.1.2-py3-none-any.whl (19 kB)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
# Installing collected packages: groq, langchain_groq
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [langchain_groq]
# Successfully installed groq-0.37.1 langchain_groq-1.1.2

# %%
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
model=ChatGroq(model="llama-3.3-70b-versatile", groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x132e24950>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x132ed7650>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
messages = [
    SystemMessage(content="Translate the following English text to French."),
    HumanMessage(content="Hello, how are you?"),
]
result=model.invoke(messages)

# %%
from langchain_core.output_parsers import StrOutputParser
parser=StrOutputParser()
parser.invoke(result)
# Out:
# 'Bonjour, comment allez-vous ?'

# %%
### using LCEL- chain the components
chain=model|parser
chain.invoke(messages)
# Out:
# 'Bonjour, comment allez-vous ?'

# %%
### Prompt Templates
from langchain_core.prompts import ChatPromptTemplate

generic_template="Translate the following into {language}:"

prompt=ChatPromptTemplate.from_messages(
    [("system", generic_template), ("user", "{text}")]
)

# %%
result=prompt.invoke({"language":"French", "text":"Hello, how are you?"})

# %%
result.to_messages()
# Out:
# [SystemMessage(content='Translate the following into French:', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Hello, how are you?', additional_kwargs={}, response_metadata={})]

# %%
chain=prompt|model|parser
chain.invoke({"language":"French", "text":"Hello, how are you?"})

### Chaining together componenents with LCEL
# Out:
# 'Bonjour, comment allez-vous ?'
